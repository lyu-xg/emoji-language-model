# %%
from magpie import MagpieModel
import pandas as pd
import numpy as np
data_folder = 'data/'
# Out:
# Using TensorFlow backend.

# %%
magpie = MagpieModel()

# %%
data_folder = 'data/'
magpie.init_word_vectors(data_folder, vec_dim=100)

# %%
from emojilist import emojis
#magpie.train(data_folder, ['smile', 'rock', 'smilecry', 'sad', 'star', 'shock', 'bullseye', 'fire'], test_ratio=0.2, nb_epochs=1000)
magpie.train(data_folder, emojis, test_ratio=0.2, nb_epochs=1000)
# Out:
# WARNING! Overwriting already trained Keras model.
# Train on 4388 samples, validate on 1098 samples
# Epoch 1/1000
# 4388/4388 [==============================] - 33s - loss: 0.0738 - acc: 0.9872 - val_loss: 0.0163 - val_acc: 0.9985
# Epoch 2/1000
# 4388/4388 [==============================] - 32s - loss: 0.0146 - acc: 0.9985 - val_loss: 0.0134 - val_acc: 0.9985
# Epoch 3/1000
# 4388/4388 [==============================] - 32s - loss: 0.0125 - acc: 0.9985 - val_loss: 0.0118 - val_acc: 0.9985
# Epoch 4/1000
# 4388/4388 [==============================] - 33s - loss: 0.0112 - acc: 0.9985 - val_loss: 0.0107 - val_acc: 0.9985
# Epoch 5/1000
# 4388/4388 [==============================] - 34s - loss: 0.0103 - acc: 0.9985 - val_loss: 0.0100 - val_acc: 0.9985
# Epoch 6/1000
# 4388/4388 [==============================] - 35s - loss: 0.0097 - acc: 0.9985 - val_loss: 0.0094 - val_acc: 0.9985
# Epoch 7/1000
# ...

# %%
magpie.predict_from_text("I am a rock star")
# Out:
# [('️', 0.2355018),
#  ('😂', 0.048456863),
#  ('👀', 0.042790454),
#  ('👅', 0.039493464),
#  ('❤', 0.039366409),
#  ('😞', 0.027208645),
#  ('😩', 0.022389613),
#  ('😢', 0.0167825),
#  ('🤦', 0.012890162),
#  ('♂', 0.012686804),
#  ('😕', 0.012605361),
#  ('🏾', 0.012542351),
#  ('\u200d', 0.010253092),
#  ('🤕', 0.010115738),
#  ('😊', 0.008009539),
#  ('🙃', 0.007023362),
#  ('🙄', 0.0066475803),
#  ('😭', 0.0066473628),
#  ('🗣', 0.0065002311),
#  ('😇', 0.0064295218),
#  ('🎶', 0.0063803568),
#  ('💪', 0.0057288888),
#  ('😰', 0.0046608755),
#  ('😍', 0.003942492),
#  ('😏', 0.0038342515),
#  ('🤗', 0.0037363004),
#  ('💰', 0.0035897938),
#  ('🏻', 0.0034841741),
#  ('😬', 0.0034721603),
#  ('😁', 0.0033335735),
#  ('☹', 0.0033288638),
#  ('💀', 0.0033044161),
#  ('🤔', 0.0031843872),
#  ('💔', 0.0031718686),
#  ('♀', 0.0030487827),
#  ('🏃', 0.0027972148),
#  ('😤', 0.0026379507),
#  ('👍', 0.0024745751),
#  ('🏼', 0.0023982797),
#  ('👉', 0.0023284382),
#  ('😑', 0.0022704212),
#  ('💁', 0.0022171629),
# ...

# %%
#magpie.save_word2vec_model('save/embeddings')

# %%
#get_all_labels()

# %%
def save_stuff(prefix):
    magpie.save_word2vec_model('save/my/embeddings/{}-here'.format(prefix), overwrite=True)
    magpie.save_scaler('save/my/scaler/{}-here'.format(prefix), overwrite=True)
    magpie.save_model('save/my/model/{}-here.h5'.format(prefix))

# %%
magpie.save_word2vec_model('saved_model/word2vec', overwrite=True)
magpie.save_scaler('saved_model/scaler', overwrite=True)
magpie.save_model('saved_model/keras_model.h5')
